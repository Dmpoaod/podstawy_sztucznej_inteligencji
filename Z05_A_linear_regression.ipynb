# %% [markdown]
# # Regresja liniowa

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import sklearn.linear_model as lm
import matplotlib.pyplot as plt

# %% [markdown]
# Proszę narysować wykres dowolnej funkcji na odcinku $[0,3]$.
#
# Będzie to model, który będziemy chcieli znaleźć.

# %%
f = lambda x: ((x*2-1)*(x**2-2)*(x-2)+3)
x_tr = np.linspace(0, 3, 200)
y_tr = f(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr[:200], y_tr[:200], '--k');
plt.show()

# %% [markdown]
# Proszę wylosować kilka punktów z otoczenia funkcji $f(x)$.
#
# Na ich podstawie będziemy wykonywać naszej presykcji.

# %%
x = stats.uniform(0,3).rvs(100)
y = f(x) + stats.norm(0,0.2).rvs(len(x))
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# Nauczmy prosty model regresji liniowej
#
# $$
# y=a\cdot x + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.
# My narazie urzyjemy metody opartej na rozwiązaniu układu równań liniowych.

# %%
M1 = np.vstack( (np.ones_like(x), x) ).T
p1 = np.linalg.lstsq(M1, y, rcond=None)

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_1 = lambda x: p1[0][1] * x +p1[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_1(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M2 = np.vstack( (np.ones_like(x), x, x**2) ).T
p2 = np.linalg.lstsq(M2, y, rcond=None)

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_2 = lambda x: p2[0][2]*pow(x,2) + p2[0][1] * x + p2[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_2(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M3 = np.vstack( (np.ones_like(x), x, x**2, x**3) ).T
p3 = np.linalg.lstsq(M3, y, rcond=None)
f_lr_3 = lambda x: p3[0][3]*pow(x,3) + p3[0][2]*pow(x,2) + p3[0][1] * x + p3[0][0]
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_3(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M4 = np.vstack( (np.ones_like(x), x, x**2, x**3,x**4) ).T
p4 = np.linalg.lstsq(M4, y, rcond=None)
f_lr_4 = lambda x: p4[0][4]*pow(x,4) + p4[0][3]*pow(x,3) + p4[0][2]*pow(x,2) + p4[0][1] * x + p4[0][0]
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_4(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + a_5 \cdot x^5 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M5 = np.vstack( (np.ones_like(x), x, x**2, x**3, x**4, x**5) ).T
p5 = np.linalg.lstsq(M5, y, rcond=None)
f_lr_5 = lambda x: p5[0][5]*pow(x,5) + p5[0][4]*pow(x,4) + p5[0][3]*pow(x,3) + p5[0][2]*pow(x,2) + p5[0][1] * x + p5[0][0]
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_5(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Narysuj wszystkie wyniki na jednym wykresie.
#
# ## Która z krzywych jest najleprza?

# %% [markdown]
# # Zadanie
# Musimy mieć jakąś miarę oceny.

# %%
import statsmodels.api as sm
Res1 = sm.OLS(y, M1).fit()
Res2 = sm.OLS(y, M2).fit()
Res3 = sm.OLS(y, M3).fit()
Res4 = sm.OLS(y, M4).fit()
Res5 = sm.OLS(y, M5).fit()

# %%
print(Res1.summary2())
print(".....................................")
print(Res2.summary2())
print(".....................................")
print(Res3.summary2())
print(".....................................")
print(Res4.summary2())
print(".....................................")
print(Res5.summary2())
# Out:
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.494
# Dependent Variable: y                AIC:                649.3290
# Date:               2023-04-13 10:50 BIC:                654.5394
# No. Observations:   100              Log-Likelihood:     -322.66
# Df Model:           1                F-statistic:        97.50
# Df Residuals:       98               Prob (F-statistic): 2.27e-16
# R-squared:          0.499            Scale:              37.925
# -------------------------------------------------------------------
#            Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# -------------------------------------------------------------------
# const     -3.3283     1.2374   -2.6897   0.0084   -5.7840   -0.8727
# x1         6.8173     0.6904    9.8743   0.0000    5.4472    8.1874
# -----------------------------------------------------------------
# Omnibus:              19.148       Durbin-Watson:          2.087
# Prob(Omnibus):        0.000        Jarque-Bera (JB):       23.311
# Skew:                 1.038        Prob(JB):               0.000
# Kurtosis:             4.135        Condition No.:          5
# =================================================================
#
# .....................................
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.808
# Dependent Variable: y                AIC:                553.3065
# Date:               2023-04-13 10:50 BIC:                561.1220
# No. Observations:   100              Log-Likelihood:     -273.65
# Df Model:           2                F-statistic:        209.4
# Df Residuals:       97               Prob (F-statistic): 6.41e-36
# R-squared:          0.812            Scale:              14.377
# ------------------------------------------------------------------
#             Coef.    Std.Err.     t     P>|t|    [0.025    0.975]
# ------------------------------------------------------------------
# const        8.4536    1.2000   7.0448  0.0000    6.0720   10.8353
# x1         -16.5853    1.8899  -8.7758  0.0000  -20.3362  -12.8344
# x2           7.6577    0.6026  12.7087  0.0000    6.4618    8.8536
# -----------------------------------------------------------------
# Omnibus:              9.575        Durbin-Watson:           1.952
# Prob(Omnibus):        0.008        Jarque-Bera (JB):        4.277
# Skew:                 0.248        Prob(JB):                0.118
# Kurtosis:             2.117        Condition No.:           28
# =================================================================
#
# .....................................
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.992
# Dependent Variable: y                AIC:                230.4495
# Date:               2023-04-13 10:50 BIC:                240.8702
# No. Observations:   100              Log-Likelihood:     -111.22
# Df Model:           3                F-statistic:        4349.
# Df Residuals:       96               Prob (F-statistic): 2.21e-102
# R-squared:          0.993            Scale:              0.56408
# -------------------------------------------------------------------
#             Coef.    Std.Err.     t      P>|t|    [0.025    0.975]
# -------------------------------------------------------------------
# const       -4.2722    0.3531  -12.1008  0.0000   -4.9730   -3.5714
# x1          27.6485    0.9816   28.1671  0.0000   25.7000   29.5969
# x2         -26.7858    0.7166  -37.3802  0.0000  -28.2082  -25.3634
# x3           7.3539    0.1509   48.7477  0.0000    7.0545    7.6534
# ------------------------------------------------------------------
# Omnibus:               6.063        Durbin-Watson:           1.971
# Prob(Omnibus):         0.048        Jarque-Bera (JB):        6.205
# Skew:                  0.604        Prob(JB):                0.045
# Kurtosis:              2.823        Condition No.:           198
# ==================================================================
#
# .....................................
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     1.000
# Dependent Variable: y                AIC:                -45.6781
# Date:               2023-04-13 10:50 BIC:                -32.6522
# No. Observations:   100              Log-Likelihood:     27.839
# Df Model:           4                F-statistic:        5.246e+04
# Df Residuals:       95               Prob (F-statistic): 6.74e-158
# R-squared:          1.000            Scale:              0.035318
# --------------------------------------------------------------------
#            Coef.    Std.Err.      t       P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const     -1.0102     0.1233    -8.1931   0.0000   -1.2550   -0.7654
# x1         9.9664     0.5270    18.9122   0.0000    8.9202   11.0126
# x2        -1.9314     0.6795    -2.8425   0.0055   -3.2803   -0.5825
# x3        -5.0340     0.3288   -15.3093   0.0000   -5.6868   -4.3812
# x4         2.0043     0.0528    37.9244   0.0000    1.8994    2.1092
# ------------------------------------------------------------------
# Omnibus:               0.334        Durbin-Watson:           2.060
# Prob(Omnibus):         0.846        Jarque-Bera (JB):        0.503
# Skew:                  0.012        Prob(JB):                0.778
# Kurtosis:              2.653        Condition No.:           1531
# ==================================================================
# * The condition number is large (2e+03). This might indicate
# strong multicollinearity or other numerical problems.
# .....................................
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     1.000
# Dependent Variable: y                AIC:                -44.5746
# Date:               2023-04-13 10:50 BIC:                -28.9436
# No. Observations:   100              Log-Likelihood:     28.287
# Df Model:           5                F-statistic:        4.190e+04
# Df Residuals:       94               Prob (F-statistic): 1.08e-155
# R-squared:          1.000            Scale:              0.035375
# --------------------------------------------------------------------
#             Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const      -0.9163     0.1601   -5.7225   0.0000   -1.2342   -0.5984
# x1          9.2391     0.9503    9.7228   0.0000    7.3524   11.1259
# x2         -0.3568     1.8415   -0.1938   0.8468   -4.0131    3.2994
# x3         -6.3858     1.5056   -4.2414   0.0001   -9.3752   -3.3964
# x4          2.5009     0.5424    4.6111   0.0000    1.4240    3.5778
# x5         -0.0653     0.0710   -0.9201   0.3599   -0.2062    0.0756
# ------------------------------------------------------------------
# Omnibus:               0.048        Durbin-Watson:           2.085
# Prob(Omnibus):         0.976        Jarque-Bera (JB):        0.185
# Skew:                  0.035        Prob(JB):                0.912
# Kurtosis:              2.802        Condition No.:           11727
# ==================================================================
# * The condition number is large (1e+04). This might indicate
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # Zadanie
# Analogiczne wyniki możemy uzysklać za pomocą prostego kodu.

# %%
import statsmodels.formula.api as smf
# Turn the data into a pandas DataFrame, so that we
# can address them in the formulas with their name
df = pd.DataFrame({'x':x, 'y':y})

# Fit the models, and show the results
Res1F = smf.ols('y~x', df).fit()
Res2F = smf.ols('y ~ x+I(x**2)', df).fit()
Res3F = smf.ols('y ~ x+I(x**2)+I(x**3)', df).fit()
Res4F = smf.ols('y ~ x+I(x**2)+I(x**3)+I(x**4)', df).fit()
Res5F = smf.ols('y ~ x+I(x**2)+I(x**3)+I(x**4)+I(x**5)', df).fit()

# %%
print(Res1F.summary())
print(".....................................")
print(Res2F.summary())
print(".....................................")
print(Res3F.summary())
print(".....................................")
print(Res4F.summary())
print(".....................................")
print(Res5F.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.499
# Model:                            OLS   Adj. R-squared:                  0.494
# Method:                 Least Squares   F-statistic:                     97.50
# Date:                Thu, 13 Apr 2023   Prob (F-statistic):           2.27e-16
# Time:                        10:52:54   Log-Likelihood:                -322.66
# No. Observations:                 100   AIC:                             649.3
# Df Residuals:                      98   BIC:                             654.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -3.3283      1.237     -2.690      0.008      -5.784      -0.873
# x              6.8173      0.690      9.874      0.000       5.447       8.187
# ==============================================================================
# Omnibus:                       19.148   Durbin-Watson:                   2.087
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.311
# Skew:                           1.038   Prob(JB):                     8.67e-06
# Kurtosis:                       4.135   Cond. No.                         4.50
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.812
# Model:                            OLS   Adj. R-squared:                  0.808
# Method:                 Least Squares   F-statistic:                     209.4
# Date:                Thu, 13 Apr 2023   Prob (F-statistic):           6.41e-36
# Time:                        10:52:54   Log-Likelihood:                -273.65
# No. Observations:                 100   AIC:                             553.3
# Df Residuals:                      97   BIC:                             561.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      8.4536      1.200      7.045      0.000       6.072      10.835
# x            -16.5853      1.890     -8.776      0.000     -20.336     -12.834
# I(x ** 2)      7.6577      0.603     12.709      0.000       6.462       8.854
# ==============================================================================
# Omnibus:                        9.575   Durbin-Watson:                   1.952
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):                4.277
# Skew:                           0.248   Prob(JB):                        0.118
# Kurtosis:                       2.117   Cond. No.                         27.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.993
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                     4349.
# Date:                Thu, 13 Apr 2023   Prob (F-statistic):          2.21e-102
# Time:                        10:52:54   Log-Likelihood:                -111.22
# No. Observations:                 100   AIC:                             230.4
# Df Residuals:                      96   BIC:                             240.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -4.2722      0.353    -12.101      0.000      -4.973      -3.571
# x             27.6485      0.982     28.167      0.000      25.700      29.597
# I(x ** 2)    -26.7858      0.717    -37.380      0.000     -28.208     -25.363
# I(x ** 3)      7.3539      0.151     48.748      0.000       7.054       7.653
# ==============================================================================
# Omnibus:                        6.063   Durbin-Watson:                   1.971
# Prob(Omnibus):                  0.048   Jarque-Bera (JB):                6.205
# Skew:                           0.604   Prob(JB):                       0.0449
# Kurtosis:                       2.823   Cond. No.                         198.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 5.246e+04
# Date:                Thu, 13 Apr 2023   Prob (F-statistic):          6.74e-158
# Time:                        10:52:54   Log-Likelihood:                 27.839
# No. Observations:                 100   AIC:                            -45.68
# Df Residuals:                      95   BIC:                            -32.65
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.0102      0.123     -8.193      0.000      -1.255      -0.765
# x              9.9664      0.527     18.912      0.000       8.920      11.013
# I(x ** 2)     -1.9314      0.679     -2.843      0.005      -3.280      -0.582
# I(x ** 3)     -5.0340      0.329    -15.309      0.000      -5.687      -4.381
# I(x ** 4)      2.0043      0.053     37.924      0.000       1.899       2.109
# ==============================================================================
# Omnibus:                        0.334   Durbin-Watson:                   2.060
# Prob(Omnibus):                  0.846   Jarque-Bera (JB):                0.503
# Skew:                           0.012   Prob(JB):                        0.778
# Kurtosis:                       2.653   Cond. No.                     1.53e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.53e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 4.190e+04
# Date:                Thu, 13 Apr 2023   Prob (F-statistic):          1.08e-155
# Time:                        10:52:54   Log-Likelihood:                 28.287
# No. Observations:                 100   AIC:                            -44.57
# Df Residuals:                      94   BIC:                            -28.94
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.9163      0.160     -5.722      0.000      -1.234      -0.598
# x              9.2391      0.950      9.723      0.000       7.352      11.126
# I(x ** 2)     -0.3568      1.841     -0.194      0.847      -4.013       3.299
# I(x ** 3)     -6.3858      1.506     -4.241      0.000      -9.375      -3.396
# I(x ** 4)      2.5009      0.542      4.611      0.000       1.424       3.578
# I(x ** 5)     -0.0653      0.071     -0.920      0.360      -0.206       0.076
# ==============================================================================
# Omnibus:                        0.048   Durbin-Watson:                   2.085
# Prob(Omnibus):                  0.976   Jarque-Bera (JB):                0.185
# Skew:                           0.035   Prob(JB):                        0.912
# Kurtosis:                       2.802   Cond. No.                     1.17e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.17e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
