# %%
import numpy as np
import sklearn.datasets
from sklearn.datasets import load_iris
from sklearn.linear_model import Perceptron

# %% [markdown]
# # Zadanie 1
# Za pomoca funkcji
# ```python
# sklearn.datasets.make_moons
# ```
# wygeneruj 4 zbiory danych z parametrami:
#
# * n_samples=1000, noise=.05
# * n_samples=1000, noise=.3
# * n_samples=200, noise=.05
# * n_samples=200, noise=.3

# %%
#low noise, plenty of samples, should be easy
X, y = sklearn.datasets.make_moons(n_samples=1000, noise=.05)
X2, y2 = sklearn.datasets.make_moons(n_samples=1000, noise=.3)
X3, y3 = sklearn.datasets.make_moons(n_samples=200, noise=.05)
X4, y4 = sklearn.datasets.make_moons(n_samples=200, noise=.3)

# %%
import matplotlib.pyplot as plt

plt.scatter(X[:,0],X[:,1],c=y)
plt.show()
plt.scatter(X2[:,0],X2[:,1],c=y2)
plt.show()
plt.scatter(X3[:,0],X3[:,1],c=y3)
plt.show()
plt.scatter(X4[:,0],X4[:,1],c=y4)

plt.axis('equal')
plt.show()

# %%
iris = load_iris()
X = iris.data[:, (2, 3)]  # petal length, petal width
y = (iris.target == 0).astype(np.int)

per_clf = Perceptron(max_iter=1000, tol=1e-3, random_state=42)
per_clf.fit(X, y)

y_pred = per_clf.predict([[2, 0.5]])
# Out:
# <ipython-input-4-654e20942998>:3: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y = (iris.target == 0).astype(np.int)

# %%
from mlxtend.plotting import plot_decision_regions

# %%
from sklearn.linear_model import Perceptron
per_clf = Perceptron(random_state=42)
per_clf.fit(X, y)

per_clf2 = Perceptron(random_state=42)
per_clf2.fit(X2, y2)

per_clf3 = Perceptron(random_state=42)
per_clf3.fit(X3, y3)

per_clf4 = Perceptron(random_state=42)
per_clf4.fit(X4, y4)
# Out:
# Perceptron(random_state=42)

# %%
plot_decision_regions(X, y, clf=per_clf, legend = 2)
plt.show()
plot_decision_regions(X2, y2, clf=per_clf2, legend = 2)
plt.show()
plot_decision_regions(X3, y3, clf=per_clf3, legend = 2)
plt.show()
plot_decision_regions(X4, y4, clf=per_clf4, legend = 2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-417ca9fde119> in <cell line: 1>()
# ----> 1 plot_decision_regions(X, y, clf=per_clf, legend = 2)
#       2 plt.show()
#       3 plot_decision_regions(X2, y2, clf=per_clf2, legend = 2)
#       4 plt.show()
#       5 plot_decision_regions(X3, y3, clf=per_clf3, legend = 2)
#
# /usr/local/lib/python3.10/dist-packages/mlxtend/plotting/decision_regions.py in plot_decision_regions(X, y, clf, feature_index, filler_feature_values, filler_feature_ranges, ax, X_highlight, res, legend, hide_spines, markers, colors, scatter_kwargs, contourf_kwargs, scatter_highlight_kwargs)
#     242                antialiased=True)
#     243
# --> 244     ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())
#     245
#     246     # Scatter training data samples
#
# ...

# %% [markdown]
# # Zad.
# Naucz perceptron na danych iris i wylicz F1 score.

# %%
iris = load_iris()
X = iris.data[:, (2, 3)] 
y = (iris.target == 0).astype(np.int)
# Out:
# <ipython-input-12-b673f8b1f109>:3: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y = (iris.target == 0).astype(np.int)

# %%
iris = load_iris()
X = iris.data[:, (2, 3)] 
y = (iris.target == 0).astype(np.int) 

per_clf = Perceptron(max_iter=1000, tol=1e-3, random_state=42)
per_clf.fit(X, y)

sklearn.metrics.f1_score(y, per_clf.predict(X))
# Out:
# <ipython-input-13-42220c5f7362>:3: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y = (iris.target == 0).astype(np.int)
# 1.0
